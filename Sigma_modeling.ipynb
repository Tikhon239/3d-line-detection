# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def gaussian_function_xx(x, sigma):
    var = sigma*sigma;
    return -(x*x-var)*np.exp(-x*x/(2*var))/(np.sqrt(2*np.pi*var)*var**2);

# %%
data = np.array([[gaussian_function_xx(i-10, float(j)/2) for i in range(21)] for j in range(1, 11)])
len(data)
# Out:
# 10

# %%
plt.figure(figsize=(20, 10))
plt.plot(range(-10, 11), data[0])

# %%
plt.figure(figsize=(20, 10))
plt.plot(range(-10, 11), data[1])

# %%
plt.figure(figsize=(20, 10))
plt.plot(range(-10, 11), data[2])

# %%
plt.figure(figsize=(20, 10))
plt.plot(range(-10, 11), data[3])

# %%
plt.figure(figsize=(20, 20))
plt.subplot(421)
plt.title('-Second derivative of Gaussian kernel, Sigma = 0.5')
plt.plot(range(-10, 11), data[0])
plt.subplot(422)
plt.title('-Second derivative of Gaussian kernel, Sigma = 1')
plt.plot(range(-10, 11), data[1])
plt.subplot(423)
plt.title('-Second derivative of Gaussian kernel, Sigma = 1.5')
plt.plot(range(-10, 11), data[2])
plt.subplot(424)
plt.title('-Second derivative of Gaussian kernel, Sigma = 2')
plt.plot(range(-10, 11), data[3])

# %%
plt.figure(figsize=(20, 10))
plt.plot(range(-10, 11), data[4])

# %%
plt.figure(figsize=(20, 10))
axes = plt.gca()
axes.set_xlim([-5, 5])
for j in range(10):
    axes.plot(range(-10, 11), data[j])

# %%
from PIL import Image
img = np.array(Image.open('pix.jpg'))
img1 = map(lambda x: x.mean(), img)
plt.plot(range(-len(img1)/2, len(img1)/2), img1)

# %%
from PIL import Image
img = np.array(Image.open('pixsum.jpg'))
img1 = map(lambda x: x.mean(), img)
plt.plot(range(-len(img1)/2, len(img1)/2), img1)

# %%
from PIL import Image
img = np.array(Image.open('min.jpg'))
img1 = map(lambda x: x.mean(), img)
plt.plot(range(-len(img1)/2, len(img1)/2), img1)

# %%
from PIL import Image
img = np.array(Image.open('minsum.jpg'))
img1 = map(lambda x: x.mean(), img)
plt.plot(range(-len(img1)/2, len(img1)/2), img1)

# %%
from PIL import Image
plt.figure(figsize=(20, 5))
plt.subplot(121)
img = np.array(Image.open('min.jpg'))
img1 = map(lambda x: x.mean(), img)
plt.plot(range(-len(img1)/2, len(img1)/2), img1)
plt.subplot(122)
imgsum = np.array(Image.open('minsum.jpg'))
imgsum1 = map(lambda x: x.mean(), imgsum)
plt.plot(range(-len(imgsum1)/2, len(imgsum1)/2), imgsum1)
